# %%
#import neccessery libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
# Load dataset creditcard from local files
df= pd.read_csv(r"C:\Users\hp\Downloads\creditcard.csv")
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#load to 10 rows
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
#see the columns which types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#count duplicated values
count_duplicated = df.duplicated().sum()
count_duplicated
# Out:
# 1081

# %%
#drop duplicates values 
df = df.drop_duplicates()
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#again show duplicated is work or not
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.shape
# Out:
# (283726, 31)

# %%
count_class = df['Class'].value_counts()
count_class
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
count_class.plot(kind ='bar', rot=0)
plt.xticks(range(2), labels=['Normal', 'Fraud'])
plt.xlabel('Class')
plt.title('transcation Class Distrubtuion')
plt.ylabel('Frequency')
plt.show()

# %%
df = df.drop_duplicates()

# %%
# see the fraud and unfraud values in Class column
df = df.reset_index(drop=True)

legi= df[df.Class==0]
frau = df[df.Class == 1]

# %%
legi.shape
# Out:
# (283253, 31)

# %%
frau.shape
# Out:
# (473, 31)

# %%
plt.figure(figsize=(22,10))
corr_matrix = df.corr()
sns.heatmap(data=corr_matrix, annot=True, linewidth=0.5)
plt.show()

# %%
# Balancing and concat the values 
legi_sample = legi.sample(n=473)
df = pd.concat([legi_sample, frau], axis=0)

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96554.761099  0.019913  0.109671  0.101425 -0.053375 -0.004520
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0     -0.060401  0.017052 -0.087413  0.124142  ...  0.030907 -0.00349
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.46655
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.003729 -0.008494  0.046000 -0.004553  0.004163 -0.010002 -0.016432
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       71.970486
# 1      123.871860
#
# [2 rows x 30 columns]

# %%
X = df.drop(['Class', 'Time'], axis=1)
y = df['Class']

# %%
# import necessery Liebary 
from sklearn.model_selection import train_test_split

# %%
# run the data in train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
# fit the model by Logistic Regression
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
# know the accuracy score of train data
from sklearn.metrics import accuracy_score
accuracy_score(y_pred, y_test)
# Out:
# 0.9315789473684211

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.svm import SVC

# %%
x, y = make_classification(random_state=0)

# %%
param_grid_rf = {
'n_estimators': [50, 100, 200],
'max_depth': [None, 10, 20, 30],
'min_samples_split': [2, 5, 10]
}
param_grid_svm = {
'C': [0.1, 1, 10],
'kernel': ['linear', 'rbf'],
'gamma': [0.1, 1, 10]
}
param_grid_gb = {
'n_estimators': [50, 100, 200],
'learning_rate': [0.01, 0.1, 1],
'max_depth': [3, 4, 5]}

# %%
rf_model = RandomForestClassifier()
svm_model = SVC()
gb_model = GradientBoostingClassifier()

# %%
models = {
'Random_Forest':(rf_model, param_grid_rf), 
'SVM':(svm_model, param_grid_svm), 
'Gradient Boosting':(gb_model, param_grid_gb)
}

# %%
models = {
    'Random Forest': (RandomForestClassifier(), {
        'n_estimators': [50, 100, 200],
        'max_depth': [5, 10, 15],
        'min_samples_split': [2, 5, 10]
    }),
'Logistic Regression': (LogisticRegression(), {
        'C': [0.1, 1, 10],  # Regularization strength
        'solver': ['liblinear', 'saga'],  # Solvers available in LogisticRegression
        'max_iter': [100, 200, 300]  # Maximum number of iterations for optimization
    }),
    'SVM': (SVC(), {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf'],
        'gamma': ['scale', 'auto']
    }),
    'SVM': (SVC(), {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf'],
        'gamma': ['scale', 'auto']
    })
}

# %%
# Grid search for each model
for model_name, (model, param_grid) in models.items():
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)
    best_params = grid_search.best_params_
    best_model = grid_search.best_estimator_
    test_score = best_model.score(X_test, y_test)
    
    print(f"Model: {model_name}")
    print("Best Hyperparameters:", best_params)
    print("Test Accuracy:", test_score)
    print("Best model:", best_model)
# Out:
# Model: Random Forest
# Best Hyperparameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 200}
# Test Accuracy: 0.9210526315789473
# Best model: RandomForestClassifier(max_depth=10, n_estimators=200)
# Model: Logistic Regression
# Best Hyperparameters: {'C': 1, 'max_iter': 100, 'solver': 'liblinear'}
# Test Accuracy: 0.9315789473684211
# Best model: LogisticRegression(C=1, solver='liblinear')
# Model: SVM
# Best Hyperparameters: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Test Accuracy: 0.9421052631578948
# Best model: SVC(C=0.1, kernel='linear')
